// %% [markdown]
// ## Retrieve Metadata of Spark Metastore Tables
//
// Let us go ahead and recreate database, table and then understand how to get the metadata of a Spark Metastore table using relevant commands.

// %% [markdown]
// * We can get metadata of Spark Metastore Tables using several commands.
//   * DESCRIBE - e.g.: `DESCRIBE orders;`
//   * DESCRIBE EXTENDED - e.g.: `DESCRIBE EXTENDED orders;`
//   * DESCRIBE FORMATTED - e.g.: `DESCRIBE FORMATTED orders;`
// * **DESCRIBE** will give only field names and data types.
// * **DESCRIBE EXTENDED** will give all the metadata, but not in readable format in Hive. It is same as **DESCRIBE FORMATTED** in Spark SQL.
// * **DESCRIBE FORMATTED** will give metadata in readable format.

// %%
%sql
SELECT current_database()

// %%
%sql
CREATE DATABASE IF NOT EXISTS itversity_retail

// %%
%sql
CREATE TABLE IF NOT EXISTS itversity_retail.orders (
    order_id INT,
    order_date STRING,
    order_customer_id INT,
    order_status STRING
) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',';

// %%
%sql
USE itversity_retail

// %%
%sql
SELECT current_database()

// %%
%sql
SHOW tables

// %%
%sql
DESCRIBE orders

// %%
%sql
DESCRIBE EXTENDED orders

// %%
%sql
DESCRIBE FORMATTED orders
