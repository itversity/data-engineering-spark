// %% [markdown]
// ## Understanding Spark Metastore Warehouse Directory
//
// Let us go through the details related to Spark Metastore Warehouse Directory.

// %% [markdown]
// * A Database in Spark SQL is nothing but directory in underlying file systems like DBFS.
// * A Spark Metastore Table is nothing but directory in underlying file systems like DBFS.
// * A Partition of Spark Metastore Table is nothing but directory in underlying file systems like DBFS under table.
// * Warehouse Directory is the base directory where directories related to databases, tables go by default.
// * It is controlled by `spark.sql.warehouse.dir`. You can get the value by saying `SET spark.sql.warehouse.dir;`. However, in Databricks Environment the value is **redacted**. The default Warehouse Directory is nothing but **/user/hive/warehouse**.
// * Underlying directory for a database except for **default** database will have **.db** extension. The Warehouse Directory will be the directory for **default** database.

// %%
%sql
SET spark.sql.warehouse.dir

// %%
%sql

SHOW tables

// %%
%sql
DROP TABLE t

// %%
%sql
CREATE TABLE t(i INT)

// %%
%sql
DESCRIBE FORMATTED t

// %%
%fs ls /user/hive/warehouse/t

// %%
%sql
SHOW databases

// %%
%sql
CREATE DATABASE itversity_demo

// %%
%fs ls /user/hive/warehouse

// %%
%fs ls /user/hive/warehouse/itversity_demo.db

// %%
%sql

DROP DATABASE itversity_demo

// %%
%fs ls /user/hive/warehouse/

// %%
%sql
DROP TABLE t

// %%
%fs ls /user/hive/warehouse/
