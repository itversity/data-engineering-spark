# %% [markdown]
# ## Introduction to Overview of DBFS Commands and APIs
#
# As part of this module we will be covering all important aspects of DBFS that are required for development.
# * Using Databricks CLI
# * Getting Help or Usage
# * Listing DBFS Files using fs magic
# * Managing DBFS Directories
# * Copying files using Databricks CLI
# * Copying files from DBFS to DBFS uisng fs magic
# * Previewing data in DBFS Files
# * Getting File Metadata
