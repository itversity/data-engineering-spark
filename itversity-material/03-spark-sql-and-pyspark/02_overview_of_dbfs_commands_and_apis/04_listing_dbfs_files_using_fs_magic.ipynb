# %% [markdown]
# ## Listing DBFS Files using fs magic
#
# Now let us walk through different options we have with `%fs ls` command to list the files.

# %%
# %fs help

# %%
# %fs ls

# %% [markdown]
# * Databricks provides free data sets under **dbfs:/databricks-datasets**. You can review the details of the data sets using below command.

# %%
# %fs ls dbfs:/databricks-datasets

# %%
# %fs ls dbfs:/databricks-datasets/airlines/

# %%
dbutils.fs.ls('dbfs:/databricks-datasets/airlines/')
