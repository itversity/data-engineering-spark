# %% [markdown]
# ## Exercises - Pandas Data Frames
#
# Here are some of the Exercises related to Pandas.
# * Create Pandas Data Frames using Schema
# * Get all the orders which belong to the month of 2013 August
# * Get all the orders which belong to the months of August, September and October in 2013.
# * Get count of orders by status for the month of 2014 January
# * Get all the records from orders where there are no corresponding records in order_items
# * Get all the customers who have not placed any orders
# * Get the revenue by status

# %% [markdown]
# ### Exercise 1 - Create Pandas Data Frames using Schema
#
# Create Pandas Data Frame for orders, order_items and customers. Make sure to use **schema/retail_db/retail.json** to get the column names.

# %%
import os
import json
import csv
import pandas as pd

def get_df(base_folder, data_set_name, schema_file):
    file_names = os.listdir(f'{base_folder}/{data_set_name}')
    retail_schemas = json.load(open(schema_file))
    columns = list(map(lambda col: col['column_name'], retail_schemas[data_set_name]))
    data = []
    for file_name in file_names:
        file_path = f'{base_folder}/{data_set_name}/{file_name}'
        raw_data = open(file_path)
        data += list(raw_data)
    return pd.DataFrame(map(lambda rec: rec.split(','), data), columns=columns)

# %%
orders = get_df('/data/retail_db', 'orders', 'schemas/retail_db/retail.json')

# %%
order_items = get_df('/data/retail_db', 'order_items', 'schemas/retail_db/retail.json')

# %%
customers = get_df('/data/retail_db', 'customers', 'schemas/retail_db/retail.json')

# %%
orders.head(2)
# Out:
#   order_id             order_date order_customer_id       order_status
# 0        1  2013-07-25 00:00:00.0             11599           CLOSED\n
# 1        2  2013-07-25 00:00:00.0               256  PENDING_PAYMENT\n

# %%
order_items.head(2)
# Out:
#   order_item_id order_item_order_id order_item_product_id order_item_quantity  \
# 0             1                   1                   957                   1
# 1             2                   2                  1073                   1
#
#   order_item_subtotal order_item_product_price
# 0              299.98                 299.98\n
# 1              199.99                 199.99\n

# %%
customers.head(2)
# Out:
#   customer_id customer_fname customer_lname customer_email customer_password  \
# 0           1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1           2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
#
#            customer_street customer_city customer_state customer_zipcode
# 0       6303 Heather Plaza   Brownsville             TX          78521\n
# 1  9526 Noble Embers Ridge     Littleton             CO          80126\n

# %% [markdown]
# ### Get all the orders which belong to the month of 2013 August

# %%
orders.query("order_date.str.startswith('2013-08')")
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68705    68706  2013-08-20 00:00:00.0               130         COMPLETE\n
# 68706    68707  2013-08-23 00:00:00.0             11730         COMPLETE\n
# 68707    68708  2013-08-26 00:00:00.0              8852          ON_HOLD\n
# 68708    68709  2013-08-30 00:00:00.0              4756         COMPLETE\n
# 68709    68710  2013-08-31 00:00:00.0              9685         COMPLETE\n
#
# [5680 rows x 4 columns]

# %% [markdown]
# ### Get all the orders which belong to the months of August, September and October in 2013.

# %%
orders.query(
    '''order_date.str.startswith("2013-08") or order_date.str.startswith("2013-09") 
    or order_date.str.startswith("2013-10")'''
, engine='python')
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68737    68738  2013-10-27 00:00:00.0              1100         COMPLETE\n
# 68738    68739  2013-10-28 00:00:00.0              2528          PENDING\n
# 68739    68740  2013-10-29 00:00:00.0             10691          ON_HOLD\n
# 68740    68741  2013-10-30 00:00:00.0              5974  PENDING_PAYMENT\n
# 68741    68742  2013-10-31 00:00:00.0               197         COMPLETE\n
#
# [16856 rows x 4 columns]

# %% [markdown]
# ### Get count of orders by status for the month of 2014 January

# %%
data = orders.query('order_date.str.startswith("2014-01")')
data.groupby(orders.order_status)['order_id'].count()
# Out:
# order_status
# CANCELED\n            110
# CLOSED\n              633
# COMPLETE\n           1911
# ON_HOLD\n             365
# PAYMENT_REVIEW\n       77
# PENDING\n             635
# PENDING_PAYMENT\n    1334
# PROCESSING\n          712
# SUSPECTED_FRAUD\n     131
# Name: order_id, dtype: int64

# %% [markdown]
# ### Get all the records from orders where there are no corresponding records in order_items

# %%
orders_with_index = orders.set_index('order_id') ## set the order_id column as index

# %%
order_items_with_index = order_items.set_index('order_item_order_id') ## set the order_item_order_id as index column

# %%
result = orders_with_index.join(order_items_with_index) ## Join based on index_value. default inner join

# %%
## Return those records where order_item_id is nan. NaN in order_item_id means not placed order.
records = result.query('order_item_id.isna()')

# %%
## Drop all the columns of order_items and returns only columns of orders dataframe

records.drop(order_items_with_index.columns, axis=1)
# Out:
#                   order_date order_customer_id       order_status
# 10015  2013-09-25 00:00:00.0              3112         COMPLETE\n
# 10016  2013-09-25 00:00:00.0              1214       PROCESSING\n
# 10022  2013-09-25 00:00:00.0              2697  PENDING_PAYMENT\n
# 10031  2013-09-25 00:00:00.0              9968         COMPLETE\n
# 10035  2013-09-25 00:00:00.0              2570  PENDING_PAYMENT\n
# ...                      ...               ...                ...
# 9978   2013-09-25 00:00:00.0              3100         CANCELED\n
# 9980   2013-09-25 00:00:00.0              8261  PENDING_PAYMENT\n
# 9982   2013-09-25 00:00:00.0              4860         COMPLETE\n
# 9994   2013-09-25 00:00:00.0              9585  PENDING_PAYMENT\n
# 9996   2013-09-25 00:00:00.0             11839          PENDING\n
#
# [11452 rows x 3 columns]

# %%
## This will also gives same output
##orders[~orders.order_id.isin(order_items.order_item_order_id)]

# %% [markdown]
# ### Get all the customers who have not placed any orders

# %%
cust = customers[~customers.customer_id.isin(orders.order_customer_id)]
cust
# Out:
#       customer_id customer_fname customer_lname customer_email  \
# 218           219           Mary        Harrell      XXXXXXXXX
# 338           339           Mary         Greene      XXXXXXXXX
# 468           469          Randy          Smith      XXXXXXXXX
# 1186         1187        Dorothy        Vazquez      XXXXXXXXX
# 1480         1481          Grace          Smith      XXXXXXXXX
# 1807         1808         Albert        Ellison      XXXXXXXXX
# 2072         2073          Donna       Stephens      XXXXXXXXX
# 2095         2096           Jose         Tanner      XXXXXXXXX
# 2449         2450          James          Smith      XXXXXXXXX
# 4554         4555           Mary          Smith      XXXXXXXXX
# 4926         4927        Carolyn          Green      XXXXXXXXX
# 6071         6072        Stephen          Smith      XXXXXXXXX
# 6612         6613         Ashley          Smith      XXXXXXXXX
# 7010         7011          Kevin          Smith      XXXXXXXXX
# 7551         7552           Carl          Smith      XXXXXXXXX
# 8242         8243           Gary         Walker      XXXXXXXXX
# 8342         8343           Mary         Bolton      XXXXXXXXX
# 8574         8575           Mary        Mueller      XXXXXXXXX
# 8777         8778           Mary          Smith      XXXXXXXXX
# 8881         8882        Kenneth          Smith      XXXXXXXXX
# 9059         9060        Matthew          Patel      XXXXXXXXX
# 9314         9315           Mary          Lewis      XXXXXXXXX
# 10059       10060           Mary           Shaw      XXXXXXXXX
# 10329       10330           Mary          Smith      XXXXXXXXX
# 10438       10439           Emma          Smith      XXXXXXXXX
# 10912       10913           Mary       Williams      XXXXXXXXX
# 10957       10958           Joan          Smith      XXXXXXXXX
# 12174       12175         Amanda          Smith      XXXXXXXXX
# 12189       12190           Mary          Smith      XXXXXXXXX
# 12391       12392           Alan           Wolf      XXXXXXXXX
#
#       customer_password               customer_street         customer_city  \
# 218           XXXXXXXXX   9016 Foggy Robin Expressway                Denver
# 338           XXXXXXXXX               4271 Hazy Close            Long Beach
# 468           XXXXXXXXX         252 Golden Goose Loop   South San Francisco
# 1186          XXXXXXXXX           363 Green Goose Run               Danbury
# 1480          XXXXXXXXX          2171 Clear Lake Isle                Caguas
# 1807          XXXXXXXXX             9795 Heather Wynd              Billings
# 2072          XXXXXXXXX             9792 Cozy Corners             Sunnyvale
# 2095          XXXXXXXXX      8976 Old Hickory Landing                 Bronx
# 2449          XXXXXXXXX       4063 Little Creek Court                Newark
# 4554          XXXXXXXXX          5455 Red Lagoon Maze                Caguas
# 4926          XXXXXXXXX        7550 Sleepy View Court                Caguas
# 6071          XXXXXXXXX       849 Noble Apple Private                Malden
# 6612          XXXXXXXXX       9847 Dusty Horse Corner                Caguas
# 7010          XXXXXXXXX  1915 Thunder Hickory Freeway             Wyandotte
# 7551          XXXXXXXXX              9966 Cinder Loop                Howell
# 8242          XXXXXXXXX        2447 Stony Barn Street              New York
# 8342          XXXXXXXXX             7302 Sunny Valley                Caguas
# 8574          XXXXXXXXX     9714 Emerald Bear Lookout                Caguas
# 8777          XXXXXXXXX      4015 Tawny Rise Crescent                Caguas
# 8881          XXXXXXXXX           6754 Iron Leaf Line               Hickory
# 9059          XXXXXXXXX       7190 Silver Horse Glade             Henderson
# 9314          XXXXXXXXX       2993 Burning Dale Farms  North Richland Hills
# 10059         XXXXXXXXX    4645 Fallen Timber By-pass                Caguas
# 10329         XXXXXXXXX      3410 Lazy Shadow Pathway              Hamilton
# 10438         XXXXXXXXX      1465 Clear Elk Diversion                Caguas
# 10912         XXXXXXXXX       9113 Grand Hills Parade              San Jose
# 10957         XXXXXXXXX       8771 Middle Quail Heath           Los Angeles
# 12174         XXXXXXXXX  3729 Cinder Grove Concession             Tonawanda
# 12189         XXXXXXXXX      4462 Little Lagoon Route                 Tempe
# 12391         XXXXXXXXX    6470 Fallen Barn Autoroute             Santa Ana
#
#       customer_state customer_zipcode
# 218               CO          80219\n
# 338               CA          90805\n
# 468               CA          94080\n
# 1186              CT          06810\n
# 1480              PR          00725\n
# 1807              MT          59102\n
# 2072              CA          94087\n
# 2095              NY          10467\n
# 2449              DE          19702\n
# 4554              PR          00725\n
# 4926              PR          00725\n
# 6071              MA          02148\n
# 6612              PR          00725\n
# 7010              MI          48192\n
# 7551              MI          48843\n
# 8242              NY          10128\n
# 8342              PR          00725\n
# 8574              PR          00725\n
# 8777              PR          00725\n
# 8881              NC          28601\n
# 9059              NV          89014\n
# 9314              TX          76180\n
# 10059             PR          00725\n
# 10329             OH          45013\n
# 10438             PR          00725\n
# 10912             CA          95123\n
# 10957             CA          90024\n
# 12174             NY          14150\n
# 12189             AZ          85283\n
# 12391             CA          92704\n

# %% [markdown]
# ### Get the revenue by status

# %%
result = pd.merge(left=orders, right=order_items, how="inner", left_on="order_id", 
                  right_on="order_item_order_id", indicator=True)

# %%
result['order_item_subtotal']=result['order_item_subtotal'].astype('float')

# %%
result.groupby('order_status')['order_item_subtotal'].sum().round(2)
# Out:
# order_status
# CANCELED\n             696030.99
# CLOSED\n              3736048.79
# COMPLETE\n           11276933.69
# ON_HOLD\n             1864731.24
# PAYMENT_REVIEW\n       357841.45
# PENDING\n             3851881.28
# PENDING_PAYMENT\n     7581671.05
# PROCESSING\n          4190636.76
# SUSPECTED_FRAUD\n      766844.68
# Name: order_item_subtotal, dtype: float64
